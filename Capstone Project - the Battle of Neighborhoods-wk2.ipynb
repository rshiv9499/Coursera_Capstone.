# %% [markdown]
# Capstone Project - The Battle of Neighborhoods(week#2)
#
# Introduction
#
# "Please provide current Anaylsis of STAR Hotels in Tamilnaudu state , India"
#
# Would you recommend a location in Chennai or other cities of Tamilnadu,India to open a new STAR Hotel with includes Star Amenities"
#
# One of the Business Vendor, the stakeholder wants to open a new  hotel as company's new business. They should has many restaurants and shopping places nearby. Transportation is also an important factor. Customer can walk to commericial market place and sight seeing and near public transport facilities is perfect.
#
# Which location or area or sub urban should be suggested to the stakeholder?

# %%
import sys
import types
import pandas as pd
from ibm_botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share your notebook.
client_04c00c8260d14c19b85a479f8f8187b0 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='rY8AzHhGvzSG3xx8p5zTSP0qIe8Rnl-Cz7VwQQo59GnB',
    ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_04c00c8260d14c19b85a479f8f8187b0.get_object(Bucket='pythoncourse-donotdelete-pr-na4wsbcsia019k',Key='Hotel_TN.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
#                    hotelname  \
# 0    Hotel Raj Park (P) Ltd.
# 1               Hotel Sangam
# 2  Le Royal Meridien Chennai
# 3         Quality Inn Sabari
# 4         Radisson Hotel GRT
#
#                                              address       state  \
# 0  "180, T.T.K. Road Alwarpet,Chennai - 600018, T...  TAMIL NADU
# 1  "Collectors Office Road , Tiruchirapalli , TAM...  TAMIL NADU
# 2  "(Owned by Appu Hotels Limited)No. 1, G.S.T. R...  TAMIL NADU
# 3  "29,Thirumalai Pillai RoadT. Nagar, Chennai, T...  TAMIL NADU
# 4  "G S T Road St Thomas Mount Chennai, Chennai, ...  TAMIL NADU
#
#             type  rooms  customerrating              area   latitude  \
# 0         4 Star     89             4.0          Alwarpet  13.033643
# 1         4 Star     76             2.7   Tiruchirapalli   10.790483
# 2  5 Star Deluxe    240             3.5  St. Thomas Mount  12.980380
# 3         4 Star     72             2.0          T. Nagar  13.040503
# ...

# %%
df = df_data_1

# %%
df.shape
# Out:
# (14, 9)

# %%
df
# Out:
#                               hotelname  \
# 0               Hotel Raj Park (P) Ltd.
# 1                          Hotel Sangam
# 2             Le Royal Meridien Chennai
# 3                    Quality Inn Sabari
# 4                    Radisson Hotel GRT
# 5                        Taj Coromandel
# 6                        Taj Mount Road
# 7   The Gateway Hotel Pasumalai Madurai
# 8                              THE PARK
# 9                  The Residency Towers
# 10                     The Savera Hotel
# 11                    Trident - Chennai
# 12                              Visalam
# 13     Vivanta by Taj - Fishermans Cove
#
#                                               address       state  \
# 0   "180, T.T.K. Road Alwarpet,Chennai - 600018, T...  TAMIL NADU
# 1   "Collectors Office Road , Tiruchirapalli , TAM...  TAMIL NADU
# 2   "(Owned by Appu Hotels Limited)No. 1, G.S.T. R...  TAMIL NADU
# 3   "29,Thirumalai Pillai RoadT. Nagar, Chennai, T...  TAMIL NADU
# ...

# %% [markdown]
# The Above data has all the details of STAR Hotels in Tamilnadu State, India with current location , rating ,type , Address & area.

# %%
import pandas as pd
typegroup = df.groupby(['type']).count()
typegroup
# Out:
#                 hotelname  address  state  rooms  customerrating  area  \
# type
# 4 Star                  5        5      5      5               5     5
# 5 Star                  3        3      3      3               3     3
# 5 Star Deluxe           5        5      5      5               5     5
# Heritage Basic          1        1      1      1               1     1
#
#                 latitude  langtude
# type
# 4 Star                 5         5
# 5 Star                 3         3
# 5 Star Deluxe          5         5
# Heritage Basic         1         1

# %%
hotellist = df['hotelname'].value_counts()
hotellist
# Out:
# Taj Mount Road                         1
# Radisson Hotel GRT                     1
# Hotel Raj Park (P) Ltd.                1
# The Savera Hotel                       1
# The Gateway Hotel Pasumalai Madurai    1
# The Residency Towers                   1
# THE PARK                               1
# Le Royal Meridien Chennai              1
# Taj Coromandel                         1
# Vivanta by Taj - Fishermans Cove       1
# Trident - Chennai                      1
# Visalam                                1
# Hotel Sangam                           1
# Quality Inn Sabari                     1
# Name: hotelname, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d8a2f6789a6b> in <module>()
# ----> 1 plot(ax)
#
# NameError: name 'plot' is not defined

# %%
CLIENT_ID = 'V5Y0BGINSJOPOX0UHD3AB5Q5MX3QPIXGXPU2WWSXXLJG5JEW' # your Foursquare ID
CLIENT_SECRET = 'BJ23AGC3CUGIUF5VVHCGBEPY43R2HDZORGSG30ET5IIOFSSK' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

latitude = 13.027
longitude = 80.2707

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: V5Y0BGINSJOPOX0UHD3AB5Q5MX3QPIXGXPU2WWSXXLJG5JEW
# CLIENT_SECRET:BJ23AGC3CUGIUF5VVHCGBEPY43R2HDZORGSG30ET5IIOFSSK

# %%
search_query = 'shop'
radius = 500
VERSION = '20180604'
LIMIT = 30
print(search_query + ' .... OK!')
# Out:
# food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=V5Y0BGINSJOPOX0UHD3AB5Q5MX3QPIXGXPU2WWSXXLJG5JEW&client_secret=BJ23AGC3CUGIUF5VVHCGBEPY43R2HDZORGSG30ET5IIOFSSK&ll=13.027,80.2707&v=20180604&query=food&radius=500&limit=30'

# %% [markdown]
# Eatout,Shops,entertainment ,food facility around Hotel The recommended  location needs to have many eating and shopping venues nearby. Convenient public transport is also required. These data can be found by using FourSquare API to find these venues around the location. The radius of exploration distance is set to 500 meters, which is about 5-10 minutes walking distance.

# %%
import requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c0a65794c1f6718d4370ea0'},
#  'response': {'venues': []}}

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.49-py_0   conda-forge
#     geopy:         1.17.0-py_0 conda-forge
#
# geographiclib- 100% |################################| Time: 0:00:00  24.57 MB/s
# geopy-1.17.0-p 100% |################################| Time: 0:00:00  34.95 MB/s
# Fetching package metadata .............
# Solving package specifications: .
#
# Package plan for installation in environment /opt/conda/envs/DSX-Python35:
#
# The following NEW packages will be INSTALLED:
#
#     altair:  2.2.2-py35_1 conda-forge
#     branca:  0.3.1-py_0   conda-forge
#     folium:  0.5.0-py_0   conda-forge
#     vincent: 0.4.4-py_1   conda-forge
#
# altair-2.2.2-p 100% |################################| Time: 0:00:00  46.82 MB/s
# ...

# %%
favorite = pd.DataFrame(df, columns=['hotelname','customerrating'])
favorite
# Out:
#                               hotelname  customerrating
# 0               Hotel Raj Park (P) Ltd.             4.0
# 1                          Hotel Sangam             2.7
# 2             Le Royal Meridien Chennai             3.5
# 3                    Quality Inn Sabari             2.0
# 4                    Radisson Hotel GRT             4.4
# 5                        Taj Coromandel             4.0
# 6                        Taj Mount Road             3.8
# 7   The Gateway Hotel Pasumalai Madurai             4.1
# 8                              THE PARK             4.0
# 9                  The Residency Towers             4.5
# 10                     The Savera Hotel             4.2
# 11                    Trident - Chennai             3.9
# 12                              Visalam             2.5
# 13     Vivanta by Taj - Fishermans Cove             4.8

# %%
df.groupby("hotelname").size().plot.bar(sort_columns="customerrating")

# %%
df.groupby("area").size().plot.bar(sort_columns="type")

# %% [markdown]
# Above both bar chart explains areawise / rating hotels

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
# 1  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
#
#                          id location.cc location.country  location.distance  \
# 0  58804ae8e612f2215824d0b9          IN            India                204
# 1  53a28b0d498e6bc264a276c0          IN            India                282
#
#   location.formattedAddress  \
# 0                   [India]
# 1                   [India]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 13.025191, 'lng':...     13.025191
# 1  [{'label': 'display', 'lat': 13.02506637573242...     13.025066
#
#    location.lng                                      name    referralId
# 0     80.271043  Ration Shop & Godown - TN Civil Supplies  v-1544184279
# 1     80.272392                    Marina Park juice shop  v-1544184279

# %% [markdown]
# near by food hotel in above chennai city

# %%
search_query = 'food'
radius = 500
VERSION = '20180604'
LIMIT = 30
print(search_query + ' .... OK!')
# Out:
# food .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=V5Y0BGINSJOPOX0UHD3AB5Q5MX3QPIXGXPU2WWSXXLJG5JEW&client_secret=BJ23AGC3CUGIUF5VVHCGBEPY43R2HDZORGSG30ET5IIOFSSK&ll=13.027,80.2707&v=20180604&query=food&radius=500&limit=30'

# %%
import requests
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c0a65c09fb6b7351b92db58'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'primary': True,
#       'shortName': 'Fast Food'}],
#     'hasPerk': False,
#     'id': '50a918e7e4b041e7e1d22009',
#     'location': {'address': '3/2',
#      'cc': 'IN',
#      'city': 'Chennai',
#      'country': 'India',
#      'crossStreet': 'West Circular Road',
#      'distance': 243,
#      'formattedAddress': ['3/2 (West Circular Road)',
#       'Chennai 600028',
#       'Tamil Nadu',
#       'India'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 13.028611,
#        'lng': 80.272222}],
#      'lat': 13.028611,
#      'lng': 80.272222,
#      'postalCode': '600028',
#      'state': 'Tamil Nadu'},
# ...

# %%
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head(10)
# Out:
#                                           categories  hasPerk  \
# 0  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
# 1  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
# 2  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
# 3  [{'icon': {'suffix': '.png', 'prefix': 'https:...    False
#
#                          id   location.address location.cc location.city  \
# 0  50a918e7e4b041e7e1d22009                3/2          IN       Chennai
# 1  4e52605122710da1b3dd0c35                NaN          IN       Chennai
# 2  50292020e4b023558882bc4f  Madha Church Road          IN       Chennai
# 3  4d00c19a1fcef04db82eccb9    Karpagam Avenue          IN       Chennai
#
#   location.country location.crossStreet  location.distance  \
# 0            India   West Circular Road                243
# 1            India             Mylapore                566
# 2            India                  NaN                277
# ...

# %% [markdown]
# There are 4 food facility near 500 meters walk in place near to Hotel.

# %%
favorite.describe()
# Out:
#        customerrating
# count       14.000000
# mean         3.742857
# std          0.804520
# min          2.000000
# 25%          3.575000
# 50%          4.000000
# 75%          4.175000
# max          4.800000

# %% [markdown]
# Conclusion
# Conclusion section where you conclude the report.
# The stakeholder's problem is resolved. Stakeholder wants to find the best place to open a new STAR Chennai. So we are recommendating Chennai city location is best place for opening new Hotel which will yield more business. Tha
